# %% [markdown]
# Prepare audioset and some key hyperparameters

# %%
import pandas as pd

datapath = "audioset/"
train_df = pd.read_csv(datapath+"train.csv", sep="\t")
dev_df = pd.read_csv(datapath+"dev.csv", sep="\t")
eval_df = pd.read_csv(datapath+"eval.csv", sep="\t")

unique_labels = ['airport', 'bus', 'metro', 'metro_station',
                'park', 'public_square', 'shopping_mall',
                'street_pedestrian', 'street_traffic', 'tram']
label_dict = {}
for ind, c in enumerate(unique_labels):
    label_dict[c] = ind

n_mels = 26
feature_option = "mfcc"
gmm_n_components = 8
gmm_covariance_type = 'full'

# %% [markdown]
# Train

# %%
# extract feature
import numpy as np
from Extract_feature import extract_mfcc

# train set
train_files = list(train_df.filename)
train_labels = list(train_df.scene_label)
train_features = []
for filename in train_files:
    wav_file_path = datapath+filename
    mfcc_feature = extract_mfcc(wav_file_path, n_mels=n_mels, option=feature_option)
    train_features.append(mfcc_feature.reshape(1,-1))           # [1, frames*n_features] (flatten)
train_features = np.concatenate(train_features, axis=0)
print(f"train feature size: {train_features.shape}")

# dev set
dev_files = list(dev_df.filename)
dev_labels = list(dev_df.scene_label)
dev_labels = [label_dict[c] for c in dev_labels]
dev_features = []
for filename in dev_files:
    wav_file_path = datapath+filename
    mfcc_feature = extract_mfcc(wav_file_path, n_mels=n_mels, option=feature_option)
    dev_features.append(mfcc_feature.reshape(1,-1))             # [1, frames*n_features] (flatten)
dev_features = np.concatenate(dev_features, axis=0)
print(f"dev feature size: {dev_features.shape}")
# Out:
# train feature size: (3008, 6487)
# dev feature size: (379, 6487)

# %%
# train GMMs for each class
import numpy as np
from sklearn.mixture import GaussianMixture

gmm_classifier_dict = {}
start_pos, end_pos = 0, 0
for ind, c in enumerate(unique_labels):
    target_df = train_df[train_df.scene_label==c]
    end_pos += len(target_df)
    # print(start_pos, end_pos)
    gmm = GaussianMixture(n_components=gmm_n_components, max_iter=100, n_init=3, tol=1e-3,
                        covariance_type=gmm_covariance_type, init_params="kmeans", random_state=0)
    gmm.fit(train_features[start_pos:end_pos,:])
    start_pos = end_pos
    print(gmm.n_iter_)
    gmm_classifier_dict[ind] = gmm
# Out:
# e:\Programming_Language\Python\anaconda\ANACONDA3_2021_11\envs\pytorch_170\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# e:\Programming_Language\Python\anaconda\ANACONDA3_2021_11\envs\pytorch_170\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# e:\Programming_Language\Python\anaconda\ANACONDA3_2021_11\envs\pytorch_170\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 2
# e:\Programming_Language\Python\anaconda\ANACONDA3_2021_11\envs\pytorch_170\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# e:\Programming_Language\Python\anaconda\ANACONDA3_2021_11\envs\pytorch_170\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# e:\My_Files\Project_Personal\algorithm2022\teamwork\221225_run_gmm_full.ipynb Cell 5 in <cell line: 7>()
#      <a href='vscode-notebook-cell:/e%3A/My_Files/Project_Personal/algorithm2022/teamwork/221225_run_gmm_full.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> # print(start_pos, end_pos)
#      <a href='vscode-notebook-cell:/e%3A/My_Files/Project_Personal/algorithm2022/teamwork/221225_run_gmm_full.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a> gmm = GaussianMixture(n_components=gmm_n_components, max_iter=100, n_init=3, tol=1e-3,
#      <a href='vscode-notebook-cell:/e%3A/My_Files/Project_Personal/algorithm2022/teamwork/221225_run_gmm_full.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a>                     covariance_type=gmm_covariance_type, init_params="kmeans", random_state=0)
# ---> <a href='vscode-notebook-cell:/e%3A/My_Files/Project_Personal/algorithm2022/teamwork/221225_run_gmm_full.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> gmm.fit(train_features[start_pos:end_pos,:])
#      <a href='vscode-notebook-cell:/e%3A/My_Files/Project_Personal/algorithm2022/teamwork/221225_run_gmm_full.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a> start_pos = end_pos
#      <a href='vscode-notebook-cell:/e%3A/My_Files/Project_Personal/algorithm2022/teamwork/221225_run_gmm_full.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a> print(gmm.n_iter_)
#
# File e:\Programming_Language\Python\anaconda\ANACONDA3_2021_11\envs\pytorch_170\lib\site-packages\sklearn\mixture\_base.py:200, in BaseMixture.fit(self, X, y)
#     174 def fit(self, X, y=None):
#     175     """Estimate model parameters with the EM algorithm.
#     176
#     177     The method fits the model ``n_init`` times and sets the parameters with
#    (...)
#     198         The fitted mixture.
#     199     """
# --> 200     self.fit_predict(X, y)
#     201     return self
#
# File e:\Programming_Language\Python\anaconda\ANACONDA3_2021_11\envs\pytorch_170\lib\site-packages\sklearn\mixture\_base.py:265, in BaseMixture.fit_predict(self, X, y)
#     262 prev_lower_bound = lower_bound
#     264 log_prob_norm, log_resp = self._e_step(X)
# --> 265 self._m_step(X, log_resp)
#     266 lower_bound = self._compute_lower_bound(log_resp, log_prob_norm)
#     268 change = lower_bound - prev_lower_bound
#
# File e:\Programming_Language\Python\anaconda\ANACONDA3_2021_11\envs\pytorch_170\lib\site-packages\sklearn\mixture\_gaussian_mixture.py:751, in GaussianMixture._m_step(self, X, log_resp)
#     740 def _m_step(self, X, log_resp):
#     741     """M step.
#     742
#     743     Parameters
#    (...)
#     749         the point of each sample in X.
#     750     """
# --> 751     self.weights_, self.means_, self.covariances_ = _estimate_gaussian_parameters(
#     752         X, np.exp(log_resp), self.reg_covar, self.covariance_type
#     753     )
#     754     self.weights_ /= self.weights_.sum()
#     755     self.precisions_cholesky_ = _compute_precision_cholesky(
#     756         self.covariances_, self.covariance_type
#     757     )
#
# File e:\Programming_Language\Python\anaconda\ANACONDA3_2021_11\envs\pytorch_170\lib\site-packages\sklearn\mixture\_gaussian_mixture.py:291, in _estimate_gaussian_parameters(X, resp, reg_covar, covariance_type)
#     289 nk = resp.sum(axis=0) + 10 * np.finfo(resp.dtype).eps
#     290 means = np.dot(resp.T, X) / nk[:, np.newaxis]
# --> 291 covariances = {
#     292     "full": _estimate_gaussian_covariances_full,
#     293     "tied": _estimate_gaussian_covariances_tied,
#     294     "diag": _estimate_gaussian_covariances_diag,
#     295     "spherical": _estimate_gaussian_covariances_spherical,
#     296 }[covariance_type](resp, X, nk, means, reg_covar)
#     297 return nk, means, covariances
#
# File e:\Programming_Language\Python\anaconda\ANACONDA3_2021_11\envs\pytorch_170\lib\site-packages\sklearn\mixture\_gaussian_mixture.py:178, in _estimate_gaussian_covariances_full(resp, X, nk, means, reg_covar)
#     176 for k in range(n_components):
#     177     diff = X - means[k]
# --> 178     covariances[k] = np.dot(resp[:, k] * diff.T, diff) / nk[k]
#     179     covariances[k].flat[:: n_features + 1] += reg_covar
#     180 return covariances
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# MemoryError: Unable to allocate 321. MiB for an array with shape (6487, 6487) and data type float64

# %%
# dev
from sklearn.metrics import confusion_matrix

# find max score
pre_scores_list = []
for i in label_dict.values():
    pre_scores = gmm_classifier_dict[i].score_samples(dev_features)
    pre_scores_list.append(pre_scores.reshape(1,-1))
    # print(pre_scores.shape)
pre_scores_list = np.concatenate(pre_scores_list, axis=0)
dev_pre_labels = np.argmax(pre_scores_list, axis=0)

dev_true_labels = np.asarray(dev_labels)
dev_cm = confusion_matrix(dev_true_labels, dev_pre_labels)
dev_cm_df = pd.DataFrame(dev_cm, columns=label_dict.keys(), index=label_dict.keys())
dev_cm_df
# Out:
#                    airport  bus  metro  metro_station  park  public_square  \
# airport                 27    0      0              4     0              1
# bus                      0   33      2              1     1              0
# metro                    0    4     22              8     0              0
# metro_station            2    2      5             14     1              4
# park                     0    2      0              0    34              1
# public_square            2    3      1              1     4             13
# shopping_mall            5    0      0              2     0              4
# street_pedestrian       10    0      0              1     0              6
# street_traffic           0    0      0              0     1              4
# tram                     0    6      4              3     1              2
#
#                    shopping_mall  street_pedestrian  street_traffic  tram
# airport                        2                  3               0     0
# bus                            1                  1               0     1
# metro                          0                  0               0     3
# metro_station                  4                  4               1     0
# park                           0                  0               1     1
# public_square                  1                 12               2     0
# shopping_mall                 23                  2               0     0
# street_pedestrian              0                 20               0     1
# street_traffic                 0                  0              32     2
# tram                           0                  0               0    21

# %%
dev_acc_df = pd.DataFrame()
for c, i in label_dict.items():
    acc = dev_cm[i,i] / np.sum(dev_cm[i])
    dev_acc_df[c] = [acc]
dev_acc_df["average"] = sum(dev_acc_df.iloc[0])/len(dev_acc_df.iloc[0])
dev_acc_df
# Out:
#    airport    bus     metro  metro_station      park  public_square  \
# 0  0.72973  0.825  0.594595       0.378378  0.871795       0.333333
#
#    shopping_mall  street_pedestrian  street_traffic      tram   average
# 0       0.638889           0.526316        0.820513  0.567568  0.628612

# %% [markdown]
# Test on eval set

# %%
# extract feature
eval_files = list(eval_df.filename)
eval_labels = list(eval_df.scene_label)
eval_labels = [label_dict[c] for c in eval_labels]
eval_features = []
for filename in eval_files:
    wav_file_path = datapath+filename
    mfcc_feature = extract_mfcc(wav_file_path, n_mels=n_mels, option=feature_option)
    eval_features.append(mfcc_feature.reshape(1,-1))             # [1, frames*n_features] (flatten)
eval_features = np.concatenate(eval_features, axis=0)
print(f"eval feature size: {eval_features.shape}")
# Out:
# eval feature size: (330, 6487)

# %%
from sklearn.metrics import confusion_matrix

# find max score
pre_scores_list = []
for i in label_dict.values():
    pre_scores = gmm_classifier_dict[i].score_samples(eval_features)
    pre_scores_list.append(pre_scores.reshape(1,-1))
    # print(pre_scores.shape)
pre_scores_list = np.concatenate(pre_scores_list, axis=0)
eval_pre_labels = np.argmax(pre_scores_list, axis=0)

eval_true_labels = np.asarray(eval_labels)
eval_cm = confusion_matrix(eval_true_labels, eval_pre_labels)
eval_cm_df = pd.DataFrame(eval_cm, columns=label_dict.keys(), index=label_dict.keys())
eval_cm_df
# Out:
#                    airport  bus  metro  metro_station  park  public_square  \
# airport                 17    0      0              0     0              2
# bus                      0   21      6              0     1              0
# metro                    2    3     12              6     0              0
# metro_station            2    0      5              9     1              4
# park                     0    1      0              2    26              1
# public_square            1    0      0              0     4             16
# shopping_mall           11    0      0              3     0              1
# street_pedestrian        5    1      0              2     0              9
# street_traffic           0    1      0              0     0              3
# tram                     0    9      6              7     0              0
#
#                    shopping_mall  street_pedestrian  street_traffic  tram
# airport                        7                  7               0     0
# bus                            0                  0               0     5
# metro                          0                  1               1     8
# metro_station                  1                  4               2     5
# park                           0                  0               2     1
# public_square                  0                  5               5     2
# shopping_mall                 15                  3               0     0
# street_pedestrian              5                 10               1     0
# street_traffic                 0                  1              28     0
# tram                           0                  0               0    11

# %%
eval_acc_df = pd.DataFrame()
for c, i in label_dict.items():
    acc = eval_cm[i,i] / np.sum(eval_cm[i])
    eval_acc_df[c] = [acc]
eval_acc_df["average"] = sum(eval_acc_df.iloc[0])/len(eval_acc_df.iloc[0])
eval_acc_df
# Out:
#     airport       bus     metro  metro_station      park  public_square  \
# 0  0.515152  0.636364  0.363636       0.272727  0.787879       0.484848
#
#    shopping_mall  street_pedestrian  street_traffic      tram  average
# 0       0.454545            0.30303        0.848485  0.333333      0.5
